# %%
import pandas as pd

# %%
data = pd.read_csv("Version_Election_WinPart.csv", index_col = 0)
data = data.rename({"RegioCode":"Regiocode"}, axis = 1)
display(data)

variables = pd.read_csv("Variables/Definitiveversions/DFVARIABLES_VERSION.csv",index_col = 0)
display(variables)
# Out:
#     Regiocode  Election02  Election03  Election06  Election10  Election12  \
# 0       G1680   -0.339541   -0.077032    0.025973   -0.482371    0.138356
# 1       G1959   -0.567556    0.125609   -0.080293   -0.402013    0.550260
# 2       G0358   -0.522940    0.122979   -0.007488   -0.548921    0.323238
# 3       G0197   -0.507016   -0.024568   -0.161210   -0.345604    0.425948
# 4       G0736   -0.525493    0.107493    0.026533   -0.554451    0.351794
# ..        ...         ...         ...         ...         ...         ...
# 351     G0637   -0.477252   -0.026073    0.014387   -0.611613    0.199025
# 352     G0638   -0.597680    0.001853   -0.024729   -0.480821    0.390655
# 353     G1730   -0.350938   -0.033180   -0.085752   -0.432368    0.185393
# 354     G0879   -0.615945    0.083772   -0.060259   -0.419865    0.503244
# 355     G0193   -0.419814   -0.065632   -0.118866   -0.451690    0.219409
#
#      Election17
# 0     -0.142526
# 1     -0.268137
# 2     -0.238600
# ...

# %%
df9802 = ["Regiocode"]


df0203 = ["Regiocode"]
df0306 = ["Regiocode"]
df0610 = ["Regiocode"]
df1012 = ["Regiocode"]
df1217 = ["Regiocode"]
for column in variables:
    if column.endswith("9802"):
        df9802.append(column)
    elif column.endswith("0203"):
        df0203.append(column)
    elif column.endswith("0306"):
        df0306.append(column)
    elif column.endswith("0610"):
        df0610.append(column)
    elif column.endswith("1012"):
        df1012c.append(column)
    elif column.endswith("1217"):
        df1217.append(column)

# %%
columnlist = ["Regiocode","Population","Immigrants","Social benefits","Homeprice","Income","Bankruptcy","Population Density","Unemployment","Laborforce"]
elect9802 = variables[df9802]
display(elect9802)
elect0203 = variables[df0203 ]
elect0306 = variables[df0306]
elect0610 = variables[df0610]
elect1012 = variables[df1012]
elect1217 = variables[df1217]



newdict = {}
for column in elect9802: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect9802 = elect9802.rename(newdict, axis = 1)
elect9802.columns = columnlist
###
newdict = {}
for column in elect0203: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect0203 = elect0203.rename(newdict, axis = 1)
elect0203.columns = columnlist
####
newdict = {}
for column in elect0306: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect0306 = elect0306.rename(newdict, axis = 1)
elect0306.columns = columnlist
##

newdict = {}
for column in elect0610: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect0610 = elect0610.rename(newdict, axis = 1)
elect0610.columns = columnlist


###

newdict = {}
for column in elect1012: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect1012 = elect1012.rename(newdict, axis = 1)
elect1012.columns = columnlist

###
newdict = {}
for column in elect1217: 
    if column.startswith("avgpop"):
        newdict[column] = "Population"
    elif column.startswith("avgallo"):
        newdict[column] = "Immigrants"
    elif column.startswith("avguitk"):
        newdict[column] = "Social benefits"
    elif column.startswith("avghomep"):
        newdict[column] = "Homeprice"
    elif column.startswith("avginc"):
        newdict[column] = "Income"
    elif column.startswith("avgbankr"):
        newdict[column] = "Bankruptcy"
    elif column.startswith("Popdens"):
        newdict[column] = "Population Density"
    elif column.startswith("avgunemp"):
        newdict[column] = "Unemployment"
    elif column.startswith("avglabf"):
        newdict[column] = "Laborforce"      
elect1217 = elect1217.rename(newdict, axis = 1)
elect1217.columns = columnlist
# Out:
#     Regiocode  avgpopchangeelection9802  avgallochangeelection9802  \
# 0       G1680                  1.068825                  10.282956
# 1       G1959                  0.695107                   6.231074
# 2       G0358                  0.403693                   2.781515
# 3       G0197                  0.079268                  -0.195520
# 4       G0569                 -0.366356                  -0.247573
# ..        ...                       ...                        ...
# 351     G0637                  0.488243                   1.838580
# 352     G0638                  0.225519                   2.263532
# 353     G1730                  0.431867                   1.944921
# 354     G0879                  0.439793                   1.692770
# 355     G0193                  1.437653                   3.828993
#
#      avguitkchangeelection9802  avghomepchangeelection9802  \
# 0                    -1.869934                   24.823141
# ...

# %%
elect9802 = elect9802.merge(data[["Election02","Regiocode"]], on = "Regiocode").rename({"Election02":"Electionresult"},axis = 1)
elect0203 = elect0203.merge(data[["Election03","Regiocode"]], on = "Regiocode").rename({"Election03":"Electionresult"},axis = 1)
elect0306 = elect0306.merge(data[["Election06","Regiocode"]], on = "Regiocode").rename({"Election06":"Electionresult"},axis = 1)
elect0610 = elect0610.merge(data[["Election10","Regiocode"]], on = "Regiocode").rename({"Election10":"Electionresult"},axis = 1)
elect1012 = elect1012.merge(data[["Election12","Regiocode"]], on = "Regiocode").rename({"Election12":"Electionresult"},axis = 1)
elect1217 = elect1217.merge(data[["Election17","Regiocode"]], on = "Regiocode").rename({"Election17":"Electionresult"},axis = 1)
dflist = [elect9802,elect0203,elect0306,elect0610,elect1012]

# %%
Dataframe_thesis = pd.concat(dflist,axis = 0)

# %%
Dataframe_thesis.to_csv("/Users/ruben/Documents/Datascience & Society/Thesis/DFVariables_Election.csv")
elect1217.to_csv("/Users/ruben/Documents/Datascience & Society/Thesis/DFVariables_ElectionTEST.csv")
Dataframe_thesis_full = pd.concat([Dataframe_thesis,elect1217],axis = 0)
Dataframe_thesis_full.to_csv("/Users/ruben/Documents/Datascience & Society/Thesis/DFVariables_ElectionFULL.csv")

# %%
Dataframe_thesis
# Out:
#     Regiocode  Population  Immigrants  Social benefits  Homeprice    Income  \
# 0       G1680    1.068825   10.282956        -1.869934  24.823141  5.813264
# 1       G1959    0.695107    6.231074         0.202074  16.540965  5.210921
# 2       G0358    0.403693    2.781515        -0.132528  26.465343  5.836617
# 3       G0197    0.079268   -0.195520         1.157618  25.154637  5.755499
# 4       G0569   -0.366356   -0.247573        -0.251652  25.901639  5.690203
# ..        ...         ...         ...              ...        ...       ...
# 351     G0637    0.328183    1.469634         3.966928  -1.656670  0.000000
# 352     G0638    0.326062    1.876911         2.266697  -2.539691  0.256396
# 353     G1730   -0.078499    2.002775         0.941794  -1.339607  0.672403
# 354     G0879    0.465212    2.192951         1.874646  -2.051091  0.424127
# 355     G0193    1.043475    1.800324         2.204826  -1.575706  0.602410
#
# ...

# %%
df = Dataframe_thesis.drop(["Regiocode", "Population", "Immigrants","Population Density","Unemployment"],axis = 1)
display(df)


corr = df.corr()["Electionresult"][df.corr()["Electionresult"]<1].abs()
corr
# Out:
#      Social benefits  Homeprice    Income  Bankruptcy  Laborforce  \
# 0          -1.869934  24.823141  5.813264   22.333913    2.235031
# 1           0.202074  16.540965  5.210921   22.075703    2.584089
# 2          -0.132528  26.465343  5.836617   19.932434    1.628950
# 3           1.157618  25.154637  5.755499   17.593361    2.778095
# 4          -0.251652  25.901639  5.690203   22.287009    1.987726
# ..               ...        ...       ...         ...         ...
# 351         3.966928  -1.656670  0.000000    1.923668    0.426136
# 352         2.266697  -2.539691  0.256396    1.923668   -1.051254
# 353         0.941794  -1.339607  0.672403   13.509308    0.632716
# 354         1.874646  -2.051091  0.424127   13.301216   -0.176624
# 355         2.204826  -1.575706  0.602410   12.553296   -0.302746
#
#      Electionresult
# 0         -0.339541
# 1         -0.567556
# 2         -0.522940
# 3         -0.507016
# 4         -0.602941
# ..              ...
# 351        0.199025
# ...

# %%
df = elect1217.drop(["Regiocode", "Population", "Immigrants","Population Density","Unemployment"],axis = 1)
display(df)


corr = df.corr()["Electionresult"][df.corr()["Electionresult"]<1].abs()
corr
# Out:
#      Social benefits  Homeprice    Income  Bankruptcy  Laborforce  \
# 0          -0.758934  -2.139037  2.700639  -15.022510    4.035736
# 1           1.131766  -2.189002  2.357020  -14.632691    4.964319
# 2           0.747862  -0.476343  2.785530  -11.672040    4.231380
# 3          -0.653814  -2.667998  2.383112  -15.820925    4.014305
# 4          -0.144252  -2.139216  3.162936  -11.812285    5.637865
# ..               ...        ...       ...         ...         ...
# 351         0.865597  -1.455645  2.002689  -11.812285    4.230432
# 352         0.636833  -2.181661  1.930376  -11.812285    4.623686
# 353         0.504781  -0.992983  2.588042  -15.022510    4.035736
# 354         1.005959  -1.814104  2.260963  -14.632691    4.265187
# 355         0.167155  -0.795001  2.494712  -14.644288    4.911519
#
#      Electionresult
# 0         -0.142526
# 1         -0.268137
# 2         -0.238600
# 3         -0.125346
# 4         -0.251439
# ..              ...
# 351       -0.220132
# ...
